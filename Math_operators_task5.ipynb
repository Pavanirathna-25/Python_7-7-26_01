# %% [markdown]
# Math Module

# %% [markdown]
# ##Question **1**

# %%
## Write a program to calculate the square root of a number using the math module.
import math
math.sqrt(144)
# Out:
# 12.0

# %% [markdown]
# Question 2

# %%
## Find the cube root of a given number using mathematical operations.
math.cbrt(199)
# Out:
# 5.838272460814004

# %% [markdown]
# Question 3

# %%
## Calculate the factorial of a number using math.factorial().
math.factorial(12)
# Out:
# 479001600

# %% [markdown]
# Question 4

# %%
## Find the GCD (Greatest Common Divisor) of two numbers using math.gcd().
math.gcd(24,15)
# Out:
# 3

# %% [markdown]
# Question 5

# %%
## Find the LCM of two numbers using math.lcm().
math.lcm(12,5)
# Out:
# 60

# %% [markdown]
# Question 6

# %%
## Calculate the value of 5 raised to the power of 8 using math.pow().
math.pow(4,7)
# Out:
# 16384.0

# %% [markdown]
# Question 7

# %%
## Find the absolute value of a negative decimal number using math.fabs().
math.fabs(-34)
# Out:
# 34.0

# %% [markdown]
# Question 8

# %%
## Round a floating-point number up using math.ceil().
math.ceil(94.8)
# Out:
# 95

# %% [markdown]
# Question 9

# %%
## Round a floating-point number down using math.floor().
math.floor(87.7)
# Out:
# 87

# %% [markdown]
# Question 10

# %%
## Round a floating-point number to the nearest integer using round().
print(round(12.5))
# Out:
# 12

# %% [markdown]
# Question 11

# %%
## Find the remainder of two numbers using math.fmod()
math.fmod(11,7)
# Out:
# 4.0

# %% [markdown]
# Question 12

# %%
## Find the quotient and remainder using divmod().
print(divmod(14,9))
# Out:
# (1, 5)

# %% [markdown]
# Question 13

# %%
## Calculate the sine, cosine, and tangent of 45 degrees.
print(math.sin(45))
print(math.cos(45))
print(math.tan(45))
# Out:
# 0.8509035245341184
# 0.5253219888177297
# 1.6197751905438615

# %% [markdown]
# Question 14

# %%
## Convert an angle from degrees to radians.
angle = 45
print(math.radians(angle))
# Out:
# 0.7853981633974483

# %% [markdown]
# Question 15

# %%
## Convert an angle from radians to degrees.
radians = 1
print(math.degrees(radians))
# Out:
# 57.29577951308232

# %% [markdown]
# Question 16

# %%
## Find the logarithm (base 10) of a number using math.log10().
x = 11
math.log10(x)
# Out:
# 1.041392685158225

# %% [markdown]
# Question 17

# %%
## Find the natural logarithm of a number using math.log().
x = 3
math.log(x)
# Out:
# 1.0986122886681098

# %% [markdown]
# Question 18

# %%
## Calculate e raised to the power of x using math.exp().
x = 8
math.exp(x)
# Out:
# 2980.9579870417283

# %% [markdown]
# Question 19

# %%
## Find the value of π (pi) and Euler's number (e) from the math module.
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %% [markdown]
# Question 20

# %%
## Find the distance between two points using math.dist().
math.dist((6,0),(9,2))
# Out:
# 3.605551275463989

# %% [markdown]
# Question 21

# %%
## Calculate the hypotenuse of a right triangle using math.hypot().
math.hypot(2,10)
# Out:
# 10.198039027185569

# %% [markdown]
# Question 22

# %%
## Find the combination (nCr) using math.comb().
math.comb(10,5)
# Out:
# 252

# %% [markdown]
# Question 23

# %%
## Find the permutation (nPr) using math.perm().
math.perm(9,2)
# Out:
# 72

# %% [markdown]
# Question 24

# %%
## Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan().
print(math.isfinite(17))
print(math.isinf(5))
print(math.isnan(math.nan))
# Out:
# True
# False
# True

# %% [markdown]
# Question 25

# %%
## Find the product of all numbers in a list using math.prod().
x = (5,6,7)
math.prod(x)
# Out:
# 210

# %% [markdown]
# Question 26

# %%
## Find the sum of square roots of all numbers in a list.
import math
list = [8,6,3,9,4]
total = 0
for i in list:
    total += math.sqrt(i)
print("Sum of square roots =", total)
# Out:
# Sum of square roots = 12.009967675098245

# %% [markdown]
# Question 27

# %%
## Find the largest integer less than or equal to the square root of a given number.
n = 25
print(math.sqrt(5))
if n == math.sqrt:
  print(n)
# Out:
# 2.23606797749979

# %% [markdown]
# Question 28

# %%
## Calculate compound interest using math.pow().
P = 5000
R = 45
N = 1
T = 2
A=P*math.pow(1+R/(100*N),N*T)
CI = A-P
print(A)
print(CI)
# Out:
# 10512.5
# 5512.5

# %% [markdown]
# Question 29

# %%
## Find the area and circumference of a circle using math.pi.
r = 2
A = math.pi*r**2
print(A)
# Out:
# 12.566370614359172

# %% [markdown]
# Question 30

# %%
## Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.
import math
print("Scientific Calculator")
print("1. Square Root")
print("2. Factorial")
print("3. Logarithm")
print("4. Power")
print("5. Sine")
print("6. Cosine")
print("7. Tangent")
print("8. GCD")
print("9. LCM")
choice = int(input("Enter your choice (1-9): "))
if choice == 1:
    n = int(input("Enter a number: "))
    print("Square Root =", math.sqrt(n))
elif choice == 2:
    n = int(input("Enter a number: "))
    print("Factorial =", math.factorial(n))
elif choice == 3:
    n = int(input("Enter a number: "))
    print("Logarithm =", math.log(n))
elif choice == 4:
    a = int(input("Enter base: "))
    b = int(input("Enter exponent: "))
    print("Power =", math.pow(a, b))
elif choice == 5:
    n = int(input("Enter angle in degrees: "))
    print("Sine =", math.sin(math.radians(n)))
elif choice == 6:
    n = int(input("Enter angle in degrees: "))
    print("Cosine =", math.cos(math.radians(n)))
elif choice == 7:
    n = int(input("Enter angle in degrees: "))
    print("Tangent =", math.tan(math.radians(n)))
elif choice == 8:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("GCD =", math.gcd(a, b))
elif choice == 9:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("LCM =", math.lcm(a, b))
else:
    print("Invalid Choice")
# Out:
# Scientific Calculator
# 1. Square Root
# 2. Factorial
# 3. Logarithm
# 4. Power
# 5. Sine
# 6. Cosine
# 7. Tangent
# 8. GCD
# 9. LCM
# Enter your choice (1-9): 1
# Enter a number: 25
# Square Root = 5.0

# %% [markdown]
# Python Operators

# %% [markdown]
# Question 1

# %%
## Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.
n1=int(input("Enter the n1:"))
n2=int(input("Enter the n2:"))
print("Addition:",n1+n2)
print("Subtraction:",n1-n2)
print("Multiplication:",n1*n2)
print("Division:",n1/n2)
print("Floor division:",n1//n2)
print("Modulus:",n1%n2)
print("Exponentiation:",n1**n2)
# Out:
# Enter the n1:12
# Enter the n2:5
# Addition: 17
# Subtraction: 7
# Multiplication: 60
# Division: 2.4
# Floor division: 2
# Modulus: 2
# Exponentiation: 248832

# %% [markdown]
# Question 2

# %%
## Swap two numbers without using a third variable.
n1=int(input("Enter the n1:"))
n2=int(input("Enter the n2:"))
print("Before Swapping:",n1,n2)
print("n1=",n1)
print("n2=",n2)
n1=n1+n2
n2=n1-n2
n1=n1-n2
print("After Swapping:",n1,n2)
print("n1:",n1)
print("n2:",n2)
# Out:
# Enter the n1:10
# Enter the n2:20
# Before Swapping: 10 20
# n1= 10
# n2= 20
# After Swapping: 20 10
# n1: 20
# n2: 10

# %% [markdown]
# Question 3

# %%
## Find whether a number is even or odd using the modulus operator.
a = int(input("Enter a: "))
if a % 2 == 0:
  print(a ,"is even")
else:
  print(a, "is odd")
# Out:
# Enter a: 10
# 10 is even

# %% [markdown]
# Question 4

# %%
## Reverse a three-digit number using arithmetic operators.
x = 567
y = 789
z = x*y
print(z)
y = z/x
print(y)
# Out:
# 447363
# 789.0

# %% [markdown]
# Question 5

# %%
## Find the last digit and first digit of a given number
num = 123456
last_digit = num % 10
first_digit = num
while first_digit >= 10:
    first_digit = first_digit // 10
print("First digit:", first_digit)
print("Last digit:", last_digit)
# Out:
# First digit: 1
# Last digit: 6

# %% [markdown]
# Assignment Operators

# %% [markdown]
# Question 6

# %%
## Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.
num = int(input("Enter the num:"))
print("num =",num)
num += 1
print(num)
num -= 5
print(num)
num *= 6
print(num)
num /= 4
print(num)
num //= 2
print(num)
num %= 20
print(num)
num **= 4
print(num)
# Out:
# Enter the num:10
# num = 10
# 11
# 6
# 36
# 9.0
# 4.0
# 4.0
# 256.0

# %% [markdown]
# Question 7

# %%
## Update a bank account balance using compound assignment operators.598451
balance = int(input("Enter the account balance:"))
balance += 7000
print("Amount after credited:",balance)
balance -= 2000
print("Amount after debited:",balance)
balance *= 2
print("Amount after multiplying:",balance)
balance %= 7
print("Amount after modules:",balance)
balance //= 3
print("Amount in bank:",balance)
balance /= 5
print("Amount after dividing:",balance)
balance **= 2
print("Amount after squaring the balance:",balance)
# Out:
# Enter the account balance:10000
# Amount after credited: 17000
# Amount after debited: 15000
# Amount after multiplying: 30000
# Amount after modules: 5
# Amount in bank: 1
# Amount after dividing: 0.2
# Amount after squaring the balance: 0.04000000000000001

# %% [markdown]
# Question 8

# %%
## Calculate the total marks using += inside a loop.
n=int(input("Enter the number of subjects:"))
total = 0
for i in range(1, n+1):
  marks = int(input(f"Enter the marks for each subject {i}: "))
  total += marks
print("Total Marks:",total)
# Out:
# Enter the number of subjects:3
# Enter the marks for each subject 1: 85
# Enter the marks for each subject 2: 90
# Enter the marks for each subject 3: 70
# Total Marks: 245

# %% [markdown]
# Comparison Operators

# %% [markdown]
# Question 9

# %%
## Compare two numbers and print the larger number.
a = 12
b = 56
if a > b:
  print("larger number is: a")
else:
  print("larger number is : b")
# Out:
# larger number is : b

# %% [markdown]
# Question 10

# %%
## Check whether three numbers are equal.
a = int(input("Enter a:"))
b = int(input("Enter b:"))
c = int(input("Enter c:"))
if a == b == c:
  print("All three numbers are equal")
else:
  print("All three numbers are not equal")
# Out:
# Enter a:12
# Enter b:12
# Enter c:12
# All three numbers are equal

# %% [markdown]
# Question 11

# %%
## Find the largest among three numbers using comparison operators.
x = 19
y = 72
z = 50
if x > y and x > z:
  print(f"{x} is the largest number")
elif y > x and y > z:
  print(f"{y} is the largest number")
elif z > x and z > y:
  print(f"{z} is the largest number")
# Out:
# 72 is the largest number

# %% [markdown]
# Question 12

# %%
## Check whether a student is eligible to vote based on age.
age = int(input("Enter the age of the student :"))
if age >= 18:
  print("Student is eligible to vote")
else:
  print("Student is not eligible to vote")
# Out:
# Enter the age of the student :21
# Student is eligible to vote

# %% [markdown]
# Logical Operators

# %% [markdown]
# Question 13

# %%
## Check if a person is eligible for a loan (age > 21 AND salary > 30000).
age = int(input("Enter the age of the person:"))
salary = int(input("Enter the salary of the person:"))
if age > 21 and salary > 30000:
  print("Eligible for loan")
else:
  print("Not eligible for loan")
# Out:
# Enter the age of the person:45
# Enter the salary of the person:60000
# Eligible for loan

# %% [markdown]
# Question 14

# %%
## Check if a number lies between 10 and 100 using logical operators.
n = int(input("Enter the number:"))
if  num >= 10 or num <= 100:
  print("Accepted")
else:
  print("Access Denied")
# Out:
# Enter the number:55
# Accepted

# %% [markdown]
# Question 15

# %%
## Validate username and password using logical operators.
username = "Pavani"
userpassword = "Pavani@04"
name = input("Enter the name:")
password = input("Enter the password:")
if name == username and password == userpassword:
  print("Logging Sucessfully")
else:
  print("Unauthorized person")
# Out:
# Enter the name:Pavani
# Enter the password:Pavani@04
# Logging Sucessfully

# %% [markdown]
# Question 16

# %%
## Determine whether a year is a leap year using logical conditions.
year = int(input("Enter the year:"))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
  print(year,"It is a leap year")
else:
  print("It is not a leap year")
# Out:
# Enter the year:2024
# 2024 It is a leap year

# %% [markdown]
# Bitwise Operators

# %% [markdown]
# Question 17

# %%
## Find the bitwise AND, OR, XOR of two numbers.
a = 7
b = 4
print("Enter the bitwise (&):",a&b)
print("Enter the bitwise (|):",a|b)
print("Enter the bitwise (^):",a^b)
# Out:
# Enter the bitwise (&): 4
# Enter the bitwise (|): 7
# Enter the bitwise (^): 3

# %% [markdown]
# Question 18

# %%
## Perform left shift and right shift operations.
n1 = 100
shift = 2
print("Left shift(<<):", n1 << shift)
print("Right shift(>>):", n2 >> shift)
# Out:
# Left shift(<<): 400
# Right shift(>>): 15

# %% [markdown]
# Question 19

# %%
## Check whether a number is even using a bitwise operator.
num = 20
print(f"Enter the number :",num)
if num & 1 == 0:
  print("Number is Even")
else:
  print("Number is odd")
# Out:
# Enter the number : 20
# Number is Even

# %% [markdown]
# Question 20

# %%
## Swap two numbers using the XOR operator.
a = 5
b = 6
print("Enter a,b:",a,b)
a = a^b
b = a^b
a = a^b
print("Enter a,b:",a,b)
# Out:
# Enter a,b: 5 6
# Enter a,b: 6 5

# %% [markdown]
# Question 21

# %%
## Count how many bits are set to 1 in a number using bitwise operations.
a = 10
count = 0
while a > 0:
  count += a & 1
  a = a >> 1
print("No.of bits in the set:",count)
# Out:
# No.of bits in the set: 2

# %% [markdown]
# Identity Operators

# %% [markdown]
# Question 22

# %%
## Demonstrate the difference between is and ==.
a = [1,2,3]
b = [1,2,3]
print(a is b)
print(a == b)
# Out:
# False
# True

# %% [markdown]
# Question 23

# %%
## Check whether two variables refer to the same list object.
a = [1,2,3]
b = [1,2,3]
if a is b:
  print("a and b refer to the same object")
else:
    print("a and b do not refer to the same object")
if a == b:
  print("a and b have same values")
else:
  print("a and b are not having same values")
# Out:
# a and b do not refer to the same object
# a and b have same values

# %% [markdown]
# Question 24

# %%
## Show the behavior of is not with integers and lists.
x = 6
y = 6
if x is y:
  print("X is y")
else:
  print("X is not Y")
a = [1,2,3]
b = [1,2,3]
if a is b:
  print("a is b")
else:
  print("a is not b")
# Out:
# x is y
# a is not b

# %% [markdown]
# Membership Operators

# %% [markdown]
# Question 25

# %%
## Check whether a character exists in a string.
String = "Data Science"
ch = "t"
if ch in String:
  print("ch exists in String")
else:
  print("ch doestn't exist in String")
# Out:
# ch exists in String

# %% [markdown]
# Question 26

# %%
## Check whether a number exists in a list.
list = [1,2,3,4]
num = 4
num1 = 40
if num in list:
  print(num,"is exist")
else:
  print(num,"doesn't exist")
if num1 is not list:
  print(num1, "doesn't exist")
# Out:
# 4 is exist
# 40 doesn't exist

# %% [markdown]
# Question 27

# %%
## Count how many vowels in a string belong to a predefined vowel list using in.
string = "Data Science"
vowels = "aeiou"
count = 0
for ch in string:
  if ch in vowels:
    count += 1
print(f"Enter the no.of Vowels:",count)
# Out:
# Enter the no.of Vowels: 5

# %% [markdown]
# Mixed Operator Programs

# %% [markdown]
# Question 28

# %%
## Build a simple calculator using arithmetic and comparison operators.
x = int(input("Enter the number:"))
y = int(input("Enter the number"))
print("#Arthimethic operators")
print("+=",x+y)
print("-=",x-y)
print("*=",x*y)
print("**=",x**y)
print("/=",x/y)
print("//=",x//y)
print("%=",x%y)
print("#Comparison operators")
print(">=",x>y)
print("<=",x<y)
print("==",x==y)
print("!=",x!=y)
print(">=",x>=y)
print("<=",x<=y)
# Out:
# Enter the number:10
# Enter the number20
# #Arthimethic operators
# += 30
# -= -10
# *= 200
# **= 100000000000000000000
# /= 0.5
# //= 0
# %= 10
# #Comparison operators
# >= False
# <= True
# == False
# != True
# >= False
# <= True

# %% [markdown]
# Question 29

# %%
## Create a grading system using comparison and logical operators.
marks = int(input("Enter the marks:"))
if marks >= 90 and marks <= 100:
  print("Grade A")
elif marks >= 80 and marks < 90:
  print("Grade A2")
elif marks >= 70 and marks < 80:
  print("Grade B")
elif marks >= 60 and marks < 70:
  print("Grade B2")
elif marks >= 50 and marks < 60:
  print("Grade C")
elif marks >= 30 and marks < 50:
  print("Grade D")
elif marks >= 0 and marks < 30:
  print("Grade Fail")
else:
  print("Not Validated")
# Out:
# Enter the marks:77
# Grade B

# %% [markdown]
# Question 30

# %%
## Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicablea = int(input("Enter first number: "))
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
print("\nMENU")
print("1. Arithmetic Operators")
print("2. Comparison Operators")
print("3. Logical Operators")
print("4. Assignment Operators")
print("5. Membership Operators")
print("6. Identity Operators")
print("7. Bitwise Operators")
choice = int(input("Enter your choice: "))
if choice == 1:
    print("Addition =", x + y)
    print("Subtraction =", x - y)
    print("Multiplication =", x * y)
    print("Division =", x / y)
    print("Floor Division =", x // y)
    print("Modulus =", x % y)
    print("Power =", x ** y)
elif choice == 2:
    print("x > y =", x > y)
    print("x < y =", x < y)
    print("x == y =", x == y)
    print("x != y =", x != y)
    print("x >= y =", x >= y)
    print("x <= y =", x <= y)

elif choice == 3:
    print("AND =", x > 0 and y > 0)
    print("OR =", x > 0 or y > 0)
    print("NOT =", not(x > y))
elif choice == 4:
    a = x
    a += y
    print("After += :", a)
    a -= y
    print("After -= :", a)
    a *= y
    print("After *= :", a)
elif choice == 5:
    nums = [10, 20, 30, 40, 50]
    print("x in nums =", x in nums)
    print("x not in nums =", x not in nums)
elif choice == 6:
    a = x
    b = a
    print("a is b =", a is b)
    print("a is not y =", a is not y)
elif choice == 7:
    print("AND =", x & y)
    print("OR =", x | y)
    print("XOR =", x ^ y)
    print("Left Shift =", x << 1)
    print("Right Shift =", x >> 1)
else:
    print("Invalid Choice")
# Out:
# Enter first number: 10
# Enter second number: 5
#
# MENU
# 1. Arithmetic Operators
# 2. Comparison Operators
# 3. Logical Operators
# 4. Assignment Operators
# 5. Membership Operators
# 6. Identity Operators
# 7. Bitwise Operators
# Enter your choice: 1
# Addition = 15
# Subtraction = 5
# Multiplication = 50
# Division = 2.0
# Floor Division = 2
# Modulus = 0
# Power = 100000
